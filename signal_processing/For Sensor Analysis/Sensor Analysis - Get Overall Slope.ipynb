# %%
# %matplotlib nbagg
#Import required libraries
from serial import Serial
import csv
import time
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.animation as animation
from scipy import stats
import pandas as pd

# %%
def get_slope(x,y):
    slope = plot_slope(x,y)
    density = 1 #in g/mL
    time_conversion = 60
    flow_rate = np.multiply(slope,1/density*time_conversion)
    return flow_rate
def plot_slope(x,y):
    slope, intercept, r, p, std_err = stats.linregress(x, y)
    def myfunc(x):
        return slope * x + intercept
    mymodel = list(map(myfunc, x))
    fig,ax = plt.subplots(1, 1)
    ax.plot(x,y)
    ax.plot(x, mymodel)
    plt.show()
    return slope
# def get_flowrate(mass_rate):
#     density = 1 #in g/mL
#     time_conversion = 60
#     flow_rate = mass_rate/density*time_conversion
#     return flow_rate

# %%
#Empty Syringe
#Get y array
csv_name = '\\Validation Results - Empty Syringe.csv'
csv_path =r'C:\Users\a_hop\repos\fydp-neofeed\sensor_data\2022-02-05 Model Validation'+csv_name
csv_data_light_measured = pd.read_csv(csv_path)
slope_1 = get_slope(csv_data_light_measured['Time'],csv_data_light_measured['Trial 1'])
slope_2 = get_slope(csv_data_light_measured['Time'],csv_data_light_measured['Trial 2'])
slope_3 = get_slope(csv_data_light_measured['Time'],csv_data_light_measured['Trial 3'])
print(slope_1)
print(slope_2)
print(slope_3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# 0.5005186813186813
# 0.7171780219780218
# 0.6121318681318682

# %%
#Half Empty Syringe
#Get y array
csv_name = '\\Validation Results - Half Empty Syringe.csv'
csv_path =r'C:\Users\a_hop\repos\fydp-neofeed\sensor_data\2022-02-05 Model Validation'+csv_name
csv_data_light_measured = pd.read_csv(csv_path)
slope_1 = get_slope(csv_data_light_measured['Time'],csv_data_light_measured['Trial 1'])
slope_2 = get_slope(csv_data_light_measured['Time'],csv_data_light_measured['Trial 2'])
slope_3 = get_slope(csv_data_light_measured['Time'],csv_data_light_measured['Trial 3'])
print(slope_1)
print(slope_2)
print(slope_3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# 0.6334681318681317
# 0.659156043956044
# 0.6205714285714286

# %%
#Full Syringe
#Get y array
csv_name = '\\Validation Results - Full Syringe.csv'
csv_path =r'C:\Users\a_hop\repos\fydp-neofeed\sensor_data\2022-02-05 Model Validation'+csv_name
csv_data_light_measured = pd.read_csv(csv_path)
slope_1 = get_slope(csv_data_light_measured['Time'],csv_data_light_measured['Trial 1'])
slope_2 = get_slope(csv_data_light_measured['Time'],csv_data_light_measured['Trial 2'])
slope_3 = get_slope(csv_data_light_measured['Time'],csv_data_light_measured['Trial 3'])
print(slope_1)
print(slope_2)
print(slope_3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# 0.626083516483516
# 0.7484043956043953
# 0.7061802197802196

# %%
csv_name = '\\result_light_high.csv'
csv_path ='C:\\Users\\a_hop\\repos\\fydp-neofeed\\sensor_data'+csv_name
slope_high = get_slope(csv_path,2000,2000)
# Out:
# C:\Users\a_hop\AppData\Local\Temp/ipykernel_15108/2088761216.py:5: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y = y.flatten().astype(np.float)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15108/3799446782.py in <module>
#       1 csv_name = '\\result_light_high.csv'
#       2 csv_path ='C:\\Users\\a_hop\\repos\\fydp-neofeed\\sensor_data'+csv_name
# ----> 3 slope_high = get_slope(csv_path,2000,2000)
#
# ~\AppData\Local\Temp/ipykernel_15108/2088761216.py in get_slope(csv_path, i1, i2)
# ...

# %%
slope_high
# Out:
# 0.010889379555575182

# %%
#MEDIUM HEIGHT
csv_name = '\\result_light_medium.csv'
csv_path ='C:\\Users\\a_hop\\repos\\fydp-neofeed\\sensor_data'+csv_name
slope_med = get_slope(csv_path,2000,2800)
# Out:
# C:\Users\a_hop\AppData\Local\Temp/ipykernel_15108/2088761216.py:5: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y = y.flatten().astype(np.float)
# <img src="data:image/png;base64,..." width="640">

# %%
slope_med
# Out:
# 0.008982889991315598

# %%
#LOWEST HEIGHT
csv_name = '\\result_light_small.csv'
csv_path ='C:\\Users\\a_hop\\repos\\fydp-neofeed\\sensor_data'+csv_name
slope_small = get_slope(csv_path,2000,7000)
# Out:
# C:\Users\a_hop\AppData\Local\Temp/ipykernel_16540/2088761216.py:5: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y = y.flatten().astype(np.float)
# <img src="data:image/png;base64,..." width="640">

# %%
slope_small
# Out:
# 0.005977542767101711
