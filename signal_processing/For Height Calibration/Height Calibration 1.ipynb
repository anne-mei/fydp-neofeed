# %%
# %matplotlib nbagg
#Import required libraries
from serial import Serial
import csv
import time
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
from drawnow import drawnow, figure
from scipy import stats
import scipy.signal as signal
import pandas as pd

# %%
def plot_slope(x,y,ax):
    slope, intercept, r, p, std_err = stats.linregress(x, y)
    def myfunc(x):
        return slope * x + intercept
    mymodel = list(map(myfunc, x))
    ax.plot(x,y)
    ax.plot(x, mymodel)
    return slope

# %% [markdown]
# # 68 cm (Highest Height)

# %%
#Read real data
csv_name = r'\Calibration Testing Results - 68 cm.csv'
csv_path =r'C:\Users\a_hop\repos\fydp-neofeed\sensor_data\2022-02-05 Height Calibration'+csv_name
csv_data = pd.read_csv(csv_path)

time = csv_data['Time']

#Initialize plot
fig, (ax1, ax2,ax3) = plt.subplots(3)

trial_1_slope = plot_slope(time,csv_data['Trial 1'],ax1)
trial_2_slope = plot_slope(time,csv_data['Trial 2'],ax2)
trial_3_slope = plot_slope(time,csv_data['Trial 3'],ax3)
print(trial_1_slope)
avg_slope_68 = (1/2)*(trial_1_slope +trial_2_slope)

print("\nTrial 1 Slope: "+str(trial_1_slope))
print("\nTrial 2 Slope: "+ str(trial_2_slope))
print("\nTrial 3 Slope: "+ str(trial_3_slope))
print("\nAvg slope: "+ str(avg_slope_68))
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# 0.051332352941176475
#
# Trial 1 Slope: 0.051332352941176475
#
# Trial 2 Slope: 0.05101862745098039
#
# Trial 3 Slope: 0.04526911764705882
#
# Avg slope: 0.051175490196078435

# %% [markdown]
# # 58 cm (Second Highest)

# %%
#Read real data
csv_name = r'\Calibration Testing Results - 58 cm.csv'
csv_path =r'C:\Users\a_hop\repos\fydp-neofeed\sensor_data\2022-02-05 Height Calibration'+csv_name
csv_data = pd.read_csv(csv_path)
time = csv_data['Time'][:18]

#Initialize plot
fig1, (ax1, ax2,ax3) = plt.subplots(3)

trial_1_slope = plot_slope(time,csv_data['Trial 1'][:18],ax1)
trial_2_slope = plot_slope(time,csv_data['Trial 2'][:18],ax2)
trial_3_slope = plot_slope(time,csv_data['Trial 3'][:18],ax3)
avg_slope_58 = (1/2)*(trial_1_slope +trial_2_slope)

print("\nTrial 1 Slope: "+str(trial_1_slope))
print("\nTrial 2 Slope: "+ str(trial_2_slope))
print("\nTrial 3 Slope: "+ str(trial_3_slope))
print("\nAvg slope: "+ str(avg_slope_58))
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# Trial 1 Slope: 0.04288400412796698
#
# Trial 2 Slope: 0.04195562435500516
#
# Trial 3 Slope: 0.04510134158926729
#
# Avg slope: 0.04241981424148607

# %% [markdown]
# # 48 cm (Middle Height)

# %%
#Read real data
csv_name = r'\Calibration Testing Results - 48 cm.csv'
csv_path =r'C:\Users\a_hop\repos\fydp-neofeed\sensor_data\2022-02-05 Height Calibration'+csv_name
csv_data = pd.read_csv(csv_path)
time = csv_data['Time']

trial_1 = csv_data['Trial 1']
trial_2 = csv_data['Trial 2']
trial_3 = csv_data['Trial 3']

#Initialize plot
fig2, (ax1, ax2,ax3) = plt.subplots(3)

trial_1_slope = plot_slope(time,csv_data['Trial 1'],ax1)
trial_2_slope = plot_slope(time,csv_data['Trial 2'],ax2)
trial_3_slope = plot_slope(time,csv_data['Trial 3'],ax3)
avg_slope_48 = (1/3)*(trial_1_slope +trial_2_slope+trial_3_slope)

print("\nTrial 1 Slope: "+str(trial_1_slope))
print("\nTrial 2 Slope: "+ str(trial_2_slope))
print("\nTrial 3 Slope: "+ str(trial_3_slope))
print("\nAvg slope: "+ str(avg_slope_48))
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# Trial 1 Slope: 0.03475008469791078
#
# Trial 2 Slope: 0.03449587803500847
#
# Trial 3 Slope: 0.03396871823828346
#
# Avg slope: 0.034404893657067566

# %% [markdown]
# # 38 CM (Lower Height)

# %%
#Read real data
csv_name = r'\Calibration Testing Results - 38 cm.csv'
csv_path =r'C:\Users\a_hop\repos\fydp-neofeed\sensor_data\2022-02-05 Height Calibration'+csv_name
csv_data = pd.read_csv(csv_path)
time = csv_data['Time'][:20]

#Initialize plot
fig2, (ax1, ax2,ax3) = plt.subplots(3)

trial_1_slope = plot_slope(time,csv_data['Trial 1'][:20],ax1)
trial_2_slope = plot_slope(time,csv_data['Trial 2'][:20],ax2)
trial_3_slope = plot_slope(time,csv_data['Trial 3'][:20],ax3)
avg_slope_38 = (1/3)*(trial_1_slope +trial_2_slope+trial_3_slope)

print("\nTrial 1 Slope: "+str(trial_1_slope))
print("\nTrial 2 Slope: "+ str(trial_2_slope))
print("\nTrial 3 Slope: "+ str(trial_3_slope))
print("\nAvg slope: "+ str(avg_slope_38))
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# Trial 1 Slope: 0.02748526315789474
#
# Trial 2 Slope: 0.026940000000000002
#
# Trial 3 Slope: 0.0265596992481203
#
# Avg slope: 0.026994987468671683

# %% [markdown]
# # 28 cm (Lowest Height)

# %%
#Read real data
csv_name = r'\Calibration Testing Results - 28 cm.csv'
csv_path =r'C:\Users\a_hop\repos\fydp-neofeed\sensor_data\2022-02-05 Height Calibration'+csv_name
csv_data = pd.read_csv(csv_path)
time = csv_data['Time'][:31]

#Initialize plot
fig2, (ax1, ax2,ax3) = plt.subplots(3)

trial_1_slope = plot_slope(time,csv_data['Trial 1'][:31],ax1)
#trial_2_slope = plot_slope(time,csv_data['Trial 2'][:31],ax2) - Bad trial
trial_3_slope = plot_slope(time,csv_data['Trial 3'][:31],ax3)
avg_slope_28 = (1/2)*(trial_1_slope +trial_3_slope)

print("\nTrial 1 Slope: "+str(trial_1_slope))
#print("\nTrial 2 Slope: "+ str(trial_2_slope))
print("\nTrial 3 Slope: "+ str(trial_3_slope))
print("\nAvg slope: "+ str(avg_slope_28))
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# Trial 1 Slope: 0.01856540322580645
#
# Trial 3 Slope: 0.01895951612903226
#
# Avg slope: 0.018762459677419355

# %% [markdown]
# # Final Calibration Slope

# %%
avg_slopes = [avg_slope_68,avg_slope_58,avg_slope_48, avg_slope_38, avg_slope_28]
density_milk =1 
sec_to_min = 60
avg_flowrate = [x*sec_to_min*density_milk for x in avg_slopes]
print(avg_flowrate)
heights = [0.68,0.58,0.48,0.38,0.28]

fig3, ax1 = plt.subplots(1,1)
ax1.plot(heights,avg_flowrate)
ax1.set_xlabel('Height (cm)')
ax1.set_ylabel('Flow Rate (mL/min)')
regres_slope = plot_slope(heights,avg_flowrate,ax1)
print('Calibration slope: '+ str(regres_slope))
#print('Calibration intercept: '+str(regres_intercept))
# Out:
# [3.070529411764706, 2.545188854489164, 2.064293619424054, 1.619699248120301, 1.1257475806451613]
# <img src="data:image/png;base64,..." width="639.999974568686">
# Calibration slope: 4.815053268607953

# %% [markdown]
# This is the calibration curve for the LFP with following use cases:
# - Milk (density = 1000kg/L)
# - Temp: 5 C
# - Baby Pressure : ~1471.5 Pa
