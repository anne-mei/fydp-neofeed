# %% [markdown]
# - TO DO: Sample at least 50 seconds before and after points (get a total of 100 s - 20 dp)

# %%
# %matplotlib nbagg
#Import required libraries
from serial import Serial
import csv
import time
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
from drawnow import drawnow, figure
from scipy import stats
import scipy.signal as signal
import pandas as pd

# %%
def plot_slope(x,y,ax,is_final):
    slope, intercept, r, p, std_err = stats.linregress(x, y)
    def myfunc(x):
        return slope * x + intercept
    mymodel = list(map(myfunc, x))
    #ax.plot(x,y)
    #if is_plot:
    ax.plot(x, mymodel)
    density_milk =1 
    sec_to_min = 60
    if is_final is False:
        slope = slope*sec_to_min*density_milk
    return slope

def plot_slope2(x,y,ax,is_final,is_plot):
    slope, intercept, r, p, std_err = stats.linregress(x, y)
    def myfunc(x):
        return slope * x + intercept
    mymodel = list(map(myfunc, x))
    #ax.plot(x,y)
    if is_plot:
        ax.plot(x, mymodel,label = 'Experimental Results - Lin Reg')
    density_milk =1 
    sec_to_min = 60
    if is_final is False:
        slope = slope*sec_to_min*density_milk
    return slope

# %% [markdown]
# # 10 cm

# %%
#Read real data
csv_name = r'\Feb 26 Even More Light Sensor_Height Trials (Pressure of 0 cm) - 10cm.csv'
csv_path =r'C:\Users\a_hop\repos\fydp-neofeed\sensor_data\2022-02-26 Height Cali and Light Sensor'+csv_name
csv_data = pd.read_csv(csv_path)
#csv_data = csv_data.head(25)
time = csv_data['Time']

#Initialize plot
fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(5)

trial_1_slope = plot_slope(time[csv_data['Trial 1'].notna()],csv_data['Trial 1'].dropna(),ax1,False)
trial_2_slope = plot_slope(time[csv_data['Trial 2'].notna()],csv_data['Trial 2'].dropna(),ax2,False)
trial_3_slope = plot_slope(time[csv_data['Trial 3'].notna()],csv_data['Trial 3'].dropna(),ax3,False)
trial_4_slope = plot_slope(time[csv_data['Trial 4'].notna()],csv_data['Trial 4'].dropna(),ax4,False)
trial_5_slope = plot_slope(time[csv_data['Trial 5'].notna()],csv_data['Trial 5'].dropna(),ax5,False)

all_slopes_10 = [trial_1_slope, trial_2_slope, trial_3_slope, trial_4_slope, trial_5_slope]
avg_slope_10 = np.mean(all_slopes_10)
max_error_10 = np.max(all_slopes_10)-avg_slope_10 
min_error_10 = avg_slope_10 - np.min(all_slopes_10)

print("\nTrial 1 Slope: "+str(trial_1_slope))
print("\nTrial 2 Slope: "+ str(trial_2_slope))
print("\nTrial 3 Slope: "+ str(trial_3_slope))
print("\nTrial 4 Slope: "+ str(trial_4_slope))
print("\nTrial 5 Slope: "+ str(trial_5_slope))
print("\nAvg slope: "+ str(avg_slope_10))
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# Trial 1 Slope: 0.7699004267425321
#
# Trial 2 Slope: 0.7448335704125181
#
# Trial 3 Slope: 0.7426429587482218
#
# Trial 4 Slope: 0.8102873399715503
#
# Trial 5 Slope: 0.7474167852062591
#
# Avg slope: 0.7630162162162162

# %% [markdown]
# # 15 cm

# %%
#Read real data
csv_name = r'\Feb 26 Even More Light Sensor_Height Trials (Pressure of 0 cm) - 15cm.csv'
csv_path =r'C:\Users\a_hop\repos\fydp-neofeed\sensor_data\2022-02-26 Height Cali and Light Sensor'+csv_name
csv_data = pd.read_csv(csv_path)
#csv_data = csv_data.head(25)
time = csv_data['Time']

#Initialize plot
fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(5)

trial_1_slope = plot_slope(time[csv_data['Trial 1'].notna()],csv_data['Trial 1'].dropna(),ax1,False)
trial_2_slope = plot_slope(time[csv_data['Trial 2'].notna()],csv_data['Trial 2'].dropna(),ax2,False)
trial_3_slope = plot_slope(time[csv_data['Trial 3'].notna()],csv_data['Trial 3'].dropna(),ax3,False)
trial_4_slope = plot_slope(time[csv_data['Trial 4'].notna()],csv_data['Trial 4'].dropna(),ax4,False)
trial_5_slope = plot_slope(time[csv_data['Trial 5'].notna()],csv_data['Trial 5'].dropna(),ax5,False)

all_slopes_15 = [trial_1_slope, trial_2_slope, trial_3_slope, trial_4_slope, trial_5_slope]
avg_slope_15 = np.mean(all_slopes_15)
max_error_15 = np.max(all_slopes_15)-avg_slope_15 
min_error_15 = avg_slope_15 - np.min(all_slopes_15)

print("\nTrial 1 Slope: "+str(trial_1_slope))
print("\nTrial 2 Slope: "+ str(trial_2_slope))
print("\nTrial 3 Slope: "+ str(trial_3_slope))
print("\nTrial 4 Slope: "+ str(trial_4_slope))
print("\nTrial 5 Slope: "+ str(trial_5_slope))
print("\nAvg slope: "+ str(avg_slope_15))
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# Trial 1 Slope: 1.0274879089615936
#
# Trial 2 Slope: 0.9999260312944525
#
# Trial 3 Slope: 0.965940256045519
#
# Trial 4 Slope: 1.0182361308677097
#
# Trial 5 Slope: 1.0134224751066856
#
# Avg slope: 1.0050025604551922

# %% [markdown]
# # 20cm

# %%
#Read real data
csv_name = r'\Feb 26 Even More Light Sensor_Height Trials (Pressure of 0 cm) - 20cm.csv'
csv_path =r'C:\Users\a_hop\repos\fydp-neofeed\sensor_data\2022-02-26 Height Cali and Light Sensor'+csv_name
csv_data = pd.read_csv(csv_path)
#csv_data = csv_data.head(25)
time = csv_data['Time']

#Initialize plot
fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(5)

trial_1_slope = plot_slope(time[csv_data['Trial 1'].notna()],csv_data['Trial 1'].dropna(),ax1,False)
trial_2_slope = plot_slope(time[csv_data['Trial 2'].notna()],csv_data['Trial 2'].dropna(),ax2,False)
trial_3_slope = plot_slope(time[csv_data['Trial 3'].notna()],csv_data['Trial 3'].dropna(),ax3,False)
trial_4_slope = plot_slope(time[csv_data['Trial 4'].notna()],csv_data['Trial 4'].dropna(),ax4,False)
trial_5_slope = plot_slope(time[csv_data['Trial 5'].notna()],csv_data['Trial 5'].dropna(),ax5,False)
all_slopes_20 = [trial_1_slope, trial_2_slope, trial_3_slope, trial_4_slope, trial_5_slope]
avg_slope_20 = np.mean(all_slopes_20)
max_error_20 = np.max(all_slopes_20)-avg_slope_20
min_error_20 = avg_slope_20 - np.min(all_slopes_20)

print("\nTrial 1 Slope: "+str(trial_1_slope))
print("\nTrial 2 Slope: "+ str(trial_2_slope))
print("\nTrial 3 Slope: "+ str(trial_3_slope))
print("\nTrial 4 Slope: "+ str(trial_4_slope))
print("\nTrial 5 Slope: "+ str(trial_5_slope))
print("\nAvg slope: "+ str(avg_slope_20))
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# Trial 1 Slope: 1.209345661450925
#
# Trial 2 Slope: 1.1988506401137982
#
# Trial 3 Slope: 1.1995704125177813
#
# Trial 4 Slope: 1.2290327169274535
#
# Trial 5 Slope: 1.2232916073968705
#
# Avg slope: 1.2120182076813655

# %% [markdown]
# # 25 cm

# %%
csv_name = r'\Feb 26 Even More Light Sensor_Height Trials (Pressure of 0 cm) - 25cm.csv'
csv_path =r'C:\Users\a_hop\repos\fydp-neofeed\sensor_data\2022-02-26 Height Cali and Light Sensor'+csv_name
csv_data = pd.read_csv(csv_path)
#csv_data = csv_data.head(25)
time = csv_data['Time']

#Initialize plot
fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(5)

trial_1_slope = plot_slope(time[csv_data['Trial 1'].notna()],csv_data['Trial 1'].dropna(),ax1,False)
trial_2_slope = plot_slope(time[csv_data['Trial 2'].notna()],csv_data['Trial 2'].dropna(),ax2,False)
trial_3_slope = plot_slope(time[csv_data['Trial 3'].notna()],csv_data['Trial 3'].dropna(),ax3,False)
trial_4_slope = plot_slope(time[csv_data['Trial 4'].notna()],csv_data['Trial 4'].dropna(),ax4,False)
trial_5_slope = plot_slope(time[csv_data['Trial 5'].notna()],csv_data['Trial 5'].dropna(),ax5,False)
all_slopes_25 = [trial_1_slope, trial_2_slope, trial_3_slope, trial_4_slope, trial_5_slope]
avg_slope_25 = np.mean(all_slopes_25)
max_error_25 = np.max(all_slopes_25)-avg_slope_25 
min_error_25 = avg_slope_25 - np.min(all_slopes_25)

print("\nTrial 1 Slope: "+str(trial_1_slope))
print("\nTrial 2 Slope: "+ str(trial_2_slope))
print("\nTrial 3 Slope: "+ str(trial_3_slope))
print("\nTrial 4 Slope: "+ str(trial_4_slope))
print("\nTrial 5 Slope: "+ str(trial_5_slope))
print("\nAvg slope: "+ str(avg_slope_25))
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# Trial 1 Slope: 1.4946287339971551
#
# Trial 2 Slope: 1.4350042674253203
#
# Trial 3 Slope: 1.4164267425320056
#
# Trial 4 Slope: 1.4183385490753913
#
# Trial 5 Slope: 1.4357098150782361
#
# Avg slope: 1.4400216216216217

# %% [markdown]
# #  30 cm

# %%
#Read real data
csv_name = r'\Feb 26 Even More Light Sensor_Height Trials (Pressure of 0 cm) - 30cm.csv'
csv_path =r'C:\Users\a_hop\repos\fydp-neofeed\sensor_data\2022-02-26 Height Cali and Light Sensor'+csv_name
csv_data = pd.read_csv(csv_path)
#csv_data = csv_data.head(25)
time = csv_data['Time']

#Initialize plot
fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(5)

trial_1_slope = plot_slope(time[csv_data['Trial 1'].notna()],csv_data['Trial 1'].dropna(),ax1,False)
trial_2_slope = plot_slope(time[csv_data['Trial 2'].notna()],csv_data['Trial 2'].dropna(),ax2,False)
trial_3_slope = plot_slope(time[csv_data['Trial 3'].notna()],csv_data['Trial 3'].dropna(),ax3,False)
trial_4_slope = plot_slope(time[csv_data['Trial 4'].notna()],csv_data['Trial 4'].dropna(),ax4,False)
trial_5_slope = plot_slope(time[csv_data['Trial 5'].notna()],csv_data['Trial 5'].dropna(),ax5,False)
all_slopes_30 = [trial_1_slope, trial_2_slope, trial_3_slope, trial_4_slope, trial_5_slope]
avg_slope_30= np.mean(all_slopes_30)
max_error_30 = np.max(all_slopes_30)-avg_slope_30 
min_error_30 = avg_slope_30 - np.min(all_slopes_30)

print("\nTrial 1 Slope: "+str(trial_1_slope))
print("\nTrial 2 Slope: "+ str(trial_2_slope))
print("\nTrial 3 Slope: "+ str(trial_3_slope))
print("\nTrial 4 Slope: "+ str(trial_4_slope))
print("\nTrial 5 Slope: "+ str(trial_5_slope))
print("\nAvg slope: "+ str(avg_slope_30))
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# Trial 1 Slope: 1.5980398293029872
#
# Trial 2 Slope: 1.567100995732575
#
# Trial 3 Slope: 1.6477411095305834
#
# Trial 4 Slope: 1.5995817923186346
#
# Trial 5 Slope: 1.6676216216216215
#
# Avg slope: 1.6160170697012801

# %% [markdown]
# # Final Cali Slope

# %%
avg_slopes = [ avg_slope_30,avg_slope_25, avg_slope_20, avg_slope_15, avg_slope_10]
error_bars = [[max_error_30,max_error_25,max_error_20,max_error_15,max_error_10],[min_error_30,min_error_25,min_error_20,min_error_15,min_error_10]]
density_milk =1 
sec_to_min = 60
heights = [0.30,0.25,0.2,0.15,0.1]
print(avg_slopes)
fig3, ax1 = plt.subplots(1,1)
ax1.plot(heights,avg_slopes)
ax1.errorbar(heights,avg_slopes,yerr = error_bars)
ax1.set_xlabel('Height (m)')
ax1.set_ylabel('Flow Rate (mL/min)')
regres_slope = plot_slope(heights,avg_slopes,ax1,True)
print('Calibration slope: '+ str(regres_slope))
#print('Calibration intercept: '+str(regres_intercept))
# Out:
# [1.6160170697012801, 1.4400216216216217, 1.2120182076813655, 1.0050025604551922, 0.7630162162162162]
# <img src="data:image/png;base64,..." width="639.999974568686">
# Calibration slope: 4.282041536273115

# %% [markdown]
# # Combination Graph

# %%
#Add Model Graph
import math
import matplotlib.pyplot as plt
from scipy import stats
#assumtions:
    #assume laminar flow (Nre < 2000)
    #assume alpha = 1 (velocity profile at max)
    #assume v1 = 0 (very small flow at the start)
    #assume 1 bend for an empty bag

# variables:
g = 9.81              # gravity (m/s^2)
#q2 = 3.3333 * 10**-8  # flow rate going into baby(m^3/s)
d = 0.0011    # internal tube diameter for 5 French (m)
rho = 1035           # density of milk (kg/m^3)
l_total = 0.875       # total length of tube (m)
mu = 0.00584     # viscosity of milk (Pa*s)
#mu = 0.00444
h_full = 0.084        #height of fluid in syringe (m)
p0 = 0                # atmospheric gauge pressure 
p1 = p0 + rho*g*h_full
#h_diff = 0.15          #Height between top of syringe and bottom of tube -----> CHANGE
#p2 = rho*g*h_diff # pressure in baby's stomach (Pa)
bends = 0.00001

def get_flowrate(hf,bends):
    #v2 = (hf*rho*d**2)/(32*mu*l_total)
    v2 = 0
    a = bends
    b = 64*mu*l_total/(rho*d**2)
    c = -2*hf
    v2_1 = (-b + (b ** 2 - 4 * a * c) ** 0.5) / (2 * a)
    v2_2 = (-b - (b ** 2 - 4 * a * c) ** 0.5) / (2 * a)
    if v2_2>=v2_1:
        v2 = v2_2
    else:
        v2 = v2_1
    #v2 = (hf*rho*d**2)/(32*mu*l_total)
    flow_rate = v2*math.pi*(d/2)**2
    convertion_rate = 6*10**7
    return flow_rate*convertion_rate

def get_headloss_friction(h,h_diff):
    p2 = rho*g*h_diff # pressure in baby's stomach (Pa)
    hf = (g*h)-(p2-p1)/rho
    return hf

def plot_slope(x,y,ax):
    slope, intercept, r, p, std_err = stats.linregress(x, y)
    def myfunc(x):
        return slope * x + intercept
    mymodel = list(map(myfunc, x))
    ax.plot(x,y)
    ax.plot(x, mymodel)
    return slope

# %%
#Solve for 0 pressure
hf1_10 = get_headloss_friction(0.1,0)
hf1_15 = get_headloss_friction(0.15,0)
hf1_20 = get_headloss_friction(0.2,0)
hf1_25 = get_headloss_friction(0.25,0)
hf1_30 = get_headloss_friction(0.3,0)
flow_rate_10 = get_flowrate(hf1_10,bends)
flow_rate_15 = get_flowrate(hf1_15,bends)
flow_rate_20 = get_flowrate(hf1_20,bends)
flow_rate_25 = get_flowrate(hf1_25,bends)
flow_rate_30 = get_flowrate(hf1_30,bends)

avg_slopes = [ avg_slope_30,avg_slope_25, avg_slope_20, avg_slope_15, avg_slope_10]
error_bars = [[max_error_30,max_error_25,max_error_20,max_error_15,max_error_10],[min_error_30,min_error_25,min_error_20,min_error_15,min_error_10]]
heights = [0.30,0.25,0.2,0.15,0.1]
flowrate = [flow_rate_30,flow_rate_25,flow_rate_20,flow_rate_15,flow_rate_10]

fig1, ax1 = plt.subplots(1,1)
ax1.plot(heights,flowrate, label = 'Model Fitting Results')
#ax1.plot(heights,avg_slopes,label = 'Experimental Results - Raw')
ax1.errorbar(heights,avg_slopes,yerr = error_bars,label = 'Experimental Results - Raw')

regres_slope_model = plot_slope2(x,flowrate,ax1,True,False)
regres_slope_exp = plot_slope2(x,avg_slopes,ax1,True,True)


ax1.set_xlabel('Height (m)')
ax1.set_ylabel('Flow Rate (mL/min)')
ax1.legend()
ax1.grid()
ax1.set_title('No Head Pressure - Comparing Model Fit With Experimental Results')
print('Model slope',regres_slope_model)
print('Experimental slope',regres_slope_exp)
print(avg_flowrate )
print(avg_slopes)
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# Model slope 4.284008536329716
# Experimental slope 4.282041536273115
# [1.6450592559104071, 1.4308589425361464, 1.2166584671015643, 1.0024581537273038, 0.7882575162323995]
# [1.6160170697012801, 1.4400216216216217, 1.2120182076813655, 1.0050025604551922, 0.7630162162162162]
