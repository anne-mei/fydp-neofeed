# %% [markdown]
# - TO DO: Sample at least 50 seconds before and after points (get a total of 100 s - 20 dp)

# %%
# %matplotlib nbagg
#Import required libraries
from serial import Serial
import csv
import time
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
from drawnow import drawnow, figure
from scipy import stats
import scipy.signal as signal
import pandas as pd

# %%
def plot_slope(x,y,ax,is_final):
    slope, intercept, r, p, std_err = stats.linregress(x, y)
    def myfunc(x):
        return slope * x + intercept
    mymodel = list(map(myfunc, x))
    #ax.plot(x,y)
    ax.plot(x, mymodel)
    density_milk =1 
    sec_to_min = 60
    if is_final is False:
        slope = slope*sec_to_min*density_milk
    return slope

def plot_slope2(x,y,ax,is_final,is_plot):
    slope, intercept, r, p, std_err = stats.linregress(x, y)
    def myfunc(x):
        return slope * x + intercept
    mymodel = list(map(myfunc, x))
    #ax.plot(x,y)
    if is_plot:
        ax.plot(x, mymodel,label = 'Experimental Results - Lin Reg')
    density_milk =1 
    sec_to_min = 60
    if is_final is False:
        slope = slope*sec_to_min*density_milk
    return slope

# %% [markdown]
# # 28 cm

# %%
#Read real data
csv_name = r'\Feb 26 Even More Light Sensor_Height Trials (Pressure of 12 cm) - 28cm.csv'
csv_path =r'C:\Users\a_hop\repos\fydp-neofeed\sensor_data\2022-02-26 Height Cali and Light Sensor'+csv_name
csv_data = pd.read_csv(csv_path)
#csv_data = csv_data.head(25)
time = csv_data['Time']

#Initialize plot
fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(5)

trial_1_slope = plot_slope(time[csv_data['Trial 1'].notna()],csv_data['Trial 1'].dropna(),ax1,False)
trial_2_slope = plot_slope(time[csv_data['Trial 2'].notna()],csv_data['Trial 2'].dropna(),ax2,False)
trial_3_slope = plot_slope(time[csv_data['Trial 3'].notna()],csv_data['Trial 3'].dropna(),ax3,False)
trial_4_slope = plot_slope(time[csv_data['Trial 4'].notna()],csv_data['Trial 4'].dropna(),ax4,False)
trial_5_slope = plot_slope(time[csv_data['Trial 5'].notna()],csv_data['Trial 5'].dropna(),ax5,False)

all_slopes_28 = [trial_1_slope, trial_2_slope, trial_3_slope, trial_4_slope, trial_5_slope]
avg_slope_28 = np.mean(all_slopes_28)
max_error_28 = np.max(all_slopes_28)-avg_slope_28 
min_error_28 = avg_slope_28 - np.min(all_slopes_28)

print("\nTrial 1 Slope: "+str(trial_1_slope))
print("\nTrial 2 Slope: "+ str(trial_2_slope))
print("\nTrial 3 Slope: "+ str(trial_3_slope))
print("\nTrial 4 Slope: "+ str(trial_4_slope))
print("\nTrial 5 Slope: "+ str(trial_5_slope))
print("\nAvg slope: "+ str(avg_slope_28))
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# Trial 1 Slope: 1.531268847795164
#
# Trial 2 Slope: 1.6287112375533428
#
# Trial 3 Slope: 1.6436073968705547
#
# Trial 4 Slope: 1.5614224751066856
#
# Trial 5 Slope: 1.520694270435447
#
# Avg slope: 1.5771408455522389

# %% [markdown]
# # 33 cm

# %%
#Read real data
csv_name = r'\Feb 26 Even More Light Sensor_Height Trials (Pressure of 12 cm) - 33cm.csv'
csv_path =r'C:\Users\a_hop\repos\fydp-neofeed\sensor_data\2022-02-26 Height Cali and Light Sensor'+csv_name
csv_data = pd.read_csv(csv_path)
#csv_data = csv_data.head(25)
time = csv_data['Time']

#Initialize plot
fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(5)

trial_1_slope = plot_slope(time[csv_data['Trial 1'].notna()],csv_data['Trial 1'].dropna(),ax1,False)
trial_2_slope = plot_slope(time[csv_data['Trial 2'].notna()],csv_data['Trial 2'].dropna(),ax2,False)
trial_3_slope = plot_slope(time[csv_data['Trial 3'].notna()],csv_data['Trial 3'].dropna(),ax3,False)
trial_4_slope = plot_slope(time[csv_data['Trial 4'].notna()],csv_data['Trial 4'].dropna(),ax4,False)
trial_5_slope = plot_slope(time[csv_data['Trial 5'].notna()],csv_data['Trial 5'].dropna(),ax5,False)

all_slopes_33 = [trial_1_slope, trial_2_slope, trial_3_slope, trial_4_slope, trial_5_slope]
avg_slope_33 = np.mean(all_slopes_33)
max_error_33 = np.max(all_slopes_33)-avg_slope_33 
min_error_33 = avg_slope_33 - np.min(all_slopes_33)

print("\nTrial 1 Slope: "+str(trial_1_slope))
print("\nTrial 2 Slope: "+ str(trial_2_slope))
print("\nTrial 3 Slope: "+ str(trial_3_slope))
print("\nTrial 4 Slope: "+ str(trial_4_slope))
print("\nTrial 5 Slope: "+ str(trial_5_slope))
print("\nAvg slope: "+ str(avg_slope_33))
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# Trial 1 Slope: 1.849421538461539
#
# Trial 2 Slope: 1.8097569230769228
#
# Trial 3 Slope: 1.8149538461538466
#
# Trial 4 Slope: 1.8410861538461538
#
# Trial 5 Slope: 1.7914246153846156
#
# Avg slope: 1.8213286153846155

# %% [markdown]
# # 38cm

# %%
#Read real data
csv_name = r'\Feb 26 Even More Light Sensor_Height Trials (Pressure of 12 cm) - 38cm.csv'
csv_path =r'C:\Users\a_hop\repos\fydp-neofeed\sensor_data\2022-02-26 Height Cali and Light Sensor'+csv_name
csv_data = pd.read_csv(csv_path)
#csv_data = csv_data.head(25)
time = csv_data['Time']

#Initialize plot
fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(5)

trial_1_slope = plot_slope(time[csv_data['Trial 1'].notna()],csv_data['Trial 1'].dropna(),ax1,False)
trial_2_slope = plot_slope(time[csv_data['Trial 2'].notna()],csv_data['Trial 2'].dropna(),ax2,False)
trial_3_slope = plot_slope(time[csv_data['Trial 3'].notna()],csv_data['Trial 3'].dropna(),ax3,False)
trial_4_slope = plot_slope(time[csv_data['Trial 4'].notna()],csv_data['Trial 4'].dropna(),ax4,False)
trial_5_slope = plot_slope(time[csv_data['Trial 5'].notna()],csv_data['Trial 5'].dropna(),ax5,False)
all_slopes_38 = [trial_1_slope, trial_2_slope, trial_3_slope, trial_4_slope, trial_5_slope]
avg_slope_38 = np.mean(all_slopes_38)
max_error_38 = np.max(all_slopes_38)-avg_slope_38 
min_error_38 = avg_slope_38 - np.min(all_slopes_38)

print("\nTrial 1 Slope: "+str(trial_1_slope))
print("\nTrial 2 Slope: "+ str(trial_2_slope))
print("\nTrial 3 Slope: "+ str(trial_3_slope))
print("\nTrial 4 Slope: "+ str(trial_4_slope))
print("\nTrial 5 Slope: "+ str(trial_5_slope))
print("\nAvg slope: "+ str(avg_slope_38))
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# Trial 1 Slope: 1.977204633204633
#
# Trial 2 Slope: 1.8824555984555984
#
# Trial 3 Slope: 1.9803243243243247
#
# Trial 4 Slope: 2.0614208494208492
#
# Trial 5 Slope: 2.0727104247104244
#
# Avg slope: 1.994823166023166

# %% [markdown]
# # 43 cm

# %%
csv_name = r'\Feb 26 Even More Light Sensor_Height Trials (Pressure of 12 cm) - 43cm.csv'
csv_path =r'C:\Users\a_hop\repos\fydp-neofeed\sensor_data\2022-02-26 Height Cali and Light Sensor'+csv_name
csv_data = pd.read_csv(csv_path)
#csv_data = csv_data.head(25)
time = csv_data['Time']

#Initialize plot
fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(5)

trial_1_slope = plot_slope(time[csv_data['Trial 1'].notna()],csv_data['Trial 1'].dropna(),ax1,False)
trial_2_slope = plot_slope(time[csv_data['Trial 2'].notna()],csv_data['Trial 2'].dropna(),ax2,False)
trial_3_slope = plot_slope(time[csv_data['Trial 3'].notna()],csv_data['Trial 3'].dropna(),ax3,False)
trial_4_slope = plot_slope(time[csv_data['Trial 4'].notna()],csv_data['Trial 4'].dropna(),ax4,False)
trial_5_slope = plot_slope(time[csv_data['Trial 5'].notna()],csv_data['Trial 5'].dropna(),ax5,False)
all_slopes_43 = [trial_1_slope, trial_2_slope, trial_3_slope, trial_4_slope, trial_5_slope]
avg_slope_43 = np.mean(all_slopes_43)
max_error_43 = np.max(all_slopes_43)-avg_slope_43 
min_error_43 = avg_slope_43 - np.min(all_slopes_43)

print("\nTrial 1 Slope: "+str(trial_1_slope))
print("\nTrial 2 Slope: "+ str(trial_2_slope))
print("\nTrial 3 Slope: "+ str(trial_3_slope))
print("\nTrial 4 Slope: "+ str(trial_4_slope))
print("\nTrial 5 Slope: "+ str(trial_5_slope))
print("\nAvg slope: "+ str(avg_slope_43))
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# Trial 1 Slope: 2.260523552123552
#
# Trial 2 Slope: 2.24130193050193
#
# Trial 3 Slope: 2.2193250965250964
#
# Trial 4 Slope: 2.186108108108108
#
# Trial 5 Slope: 2.226421621621622
#
# Avg slope: 2.2267360617760614

# %% [markdown]
# #  48 cm

# %%
#Read real data
csv_name = r'\Feb 26 Even More Light Sensor_Height Trials (Pressure of 12 cm) - 48cm.csv'
csv_path =r'C:\Users\a_hop\repos\fydp-neofeed\sensor_data\2022-02-26 Height Cali and Light Sensor'+csv_name
csv_data = pd.read_csv(csv_path)
#csv_data = csv_data.head(25)
time = csv_data['Time']

#Initialize plot
fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(5)

trial_1_slope = plot_slope(time[csv_data['Trial 1'].notna()],csv_data['Trial 1'].dropna(),ax1,False)
trial_2_slope = plot_slope(time[csv_data['Trial 2'].notna()],csv_data['Trial 2'].dropna(),ax2,False)
trial_3_slope = plot_slope(time[csv_data['Trial 3'].notna()],csv_data['Trial 3'].dropna(),ax3,False)
trial_4_slope = plot_slope(time[csv_data['Trial 4'].notna()],csv_data['Trial 4'].dropna(),ax4,False)
trial_5_slope = plot_slope(time[csv_data['Trial 5'].notna()],csv_data['Trial 5'].dropna(),ax5,False)
all_slopes_48 = [trial_1_slope, trial_2_slope,trial_3_slope, trial_4_slope, trial_5_slope]
avg_slope_48 = np.mean(all_slopes_48)
max_error_48 = np.max(all_slopes_48)-avg_slope_48 
min_error_48 = avg_slope_48 - np.min(all_slopes_48)
print(max_error_48)
print("\nTrial 1 Slope: "+str(trial_1_slope))
print("\nTrial 2 Slope: "+ str(trial_2_slope))
print("\nTrial 3 Slope: "+ str(trial_3_slope))
print("\nTrial 4 Slope: "+ str(trial_4_slope))
print("\nTrial 5 Slope: "+ str(trial_5_slope))
print("\nAvg slope: "+ str(avg_slope_48))
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# 0.054976386913228925
#
# Trial 1 Slope: 2.4048136557610253
#
# Trial 2 Slope: 2.4310071123755335
#
# Trial 3 Slope: 2.30649786628734
#
# Trial 4 Slope: 2.3419886201991464
#
# Trial 5 Slope: 2.3958463726884776
#
# Avg slope: 2.3760307254623045

# %% [markdown]
# # Final Cali Slope

# %%
avg_slopes = [ avg_slope_48,avg_slope_43, avg_slope_38, avg_slope_33, avg_slope_28]
error_bars = [[max_error_48,max_error_43,max_error_38,max_error_33,max_error_28],[min_error_48,min_error_43,min_error_38,min_error_33,min_error_28]]
density_milk =1 
sec_to_min = 60
heights = [0.48,0.43,0.38,0.33,0.28]
print(avg_slopes)
fig3, ax1 = plt.subplots(1,1)
ax1.plot(heights,avg_slopes)
ax1.errorbar(heights,avg_slopes,yerr = error_bars)
ax1.set_xlabel('Height (m)')
ax1.set_ylabel('Flow Rate (mL/min)')
regres_slope = plot_slope(heights,avg_slopes,ax1,True)
print('Calibration slope: '+ str(regres_slope))
#print('Calibration intercept: '+str(regres_intercept))
# Out:
# [2.3760307254623045, 2.2267360617760614, 1.994823166023166, 1.8213286153846155, 1.5771408455522389]
# <img src="data:image/png;base64,..." width="639.999974568686">
# Calibration slope: 4.006374412423156

# %%
from scipy import stats
#assumtions:
    #assume laminar flow (Nre < 2000)
    #assume alpha = 1 (velocity profile at max)
    #assume v1 = 0 (very small flow at the start)
    #assume 1 bend for an empty bag
import math
# variables:
g = 9.81              # gravity (m/s^2)
#q2 = 3.3333 * 10**-8  # flow rate going into baby(m^3/s)
d = 0.0011    # internal tube diameter for 5 French (m)
rho = 1035           # density of milk (kg/m^3)
l_total = 0.875       # total length of tube (m)
mu = 0.00584     # viscosity of milk (Pa*s)
#mu = 0.00444
h_full = 0.084        #height of fluid in syringe (m)
p0 = 0                # atmospheric gauge pressure 
p1 = p0 + rho*g*h_full
#h_diff = 0.15          #Height between top of syringe and bottom of tube -----> CHANGE
#p2 = rho*g*h_diff # pressure in baby's stomach (Pa)
bends = 0.00001

def get_flowrate(hf,bends):
    #v2 = (hf*rho*d**2)/(32*mu*l_total)
    v2 = 0
    a = bends
    b = 64*mu*l_total/(rho*d**2)
    c = -2*hf
    v2_1 = (-b + (b ** 2 - 4 * a * c) ** 0.5) / (2 * a)
    v2_2 = (-b - (b ** 2 - 4 * a * c) ** 0.5) / (2 * a)
    if v2_2>=v2_1:
        v2 = v2_2
    else:
        v2 = v2_1
    #v2 = (hf*rho*d**2)/(32*mu*l_total)
    flow_rate = v2*math.pi*(d/2)**2
    convertion_rate = 6*10**7
    return flow_rate*convertion_rate

def get_headloss_friction(h,h_diff):
    p2 = rho*g*h_diff # pressure in baby's stomach (Pa)
    hf = (g*h)-(p2-p1)/rho
    return hf

def plot_slope(x,y,ax):
    slope, intercept, r, p, std_err = stats.linregress(x, y)
    def myfunc(x):
        return slope * x + intercept
    mymodel = list(map(myfunc, x))
    ax.plot(x,y)
    ax.plot(x, mymodel)
    return slope
#if __name__ == '__main__':
    #v2 = get_velocity_into_baby();


#SOLVE FOR 6.5 FRENCH:
    # print('\nSolved Heights for 6 French Tubing:')
    # # CASE 1: 1 Bend at mouth (90 degrees) (bag is empty)
    # hf1 = get_headloss_friction(get_velocity_into_baby(d_6French), k_bend_90deg, d_6French);
    # h_empty = get_height(hf1, 0, d_6French);
    # print('The height for an empty bag of feed should be', round(h_empty, 4), 'm above the baby\'s stomach')

    # #CASE 2: 2 Bends, one at mouth (90 degrees), one at 45 degree (bag is half empty)
    # hf2 = get_headloss_friction(get_velocity_into_baby(d_6French), k_bend_90deg + k_bend_45deg,d_6French);
    # h_semifull = get_height(hf2,p1_half_full,d_6French);
    # print('The height for a semi-full bag of feed should be', round(h_semifull, 4),'m above the baby\'s stomach')

    # #CASE 3: 2 Bends, one at mouth (90 degrees), one at 90 degree (bag is full)
    # hf3 = get_headloss_friction(get_velocity_into_baby(d_6French), k_bend_90deg + k_bend_90deg,d_6French);
    # h_fullbag = get_height(hf3, p1_full,d_6French);
    # print('The height for a full bag of feed should be', round(h_fullbag, 4), 'm above the baby\'s stomach')

# %%
#Add Model Graph
bends = 200
height_diff = 0.1
hf1_38 = get_headloss_friction(0.38,height_diff)
hf1_43 = get_headloss_friction(0.43,height_diff)
hf1_48 = get_headloss_friction(0.48,height_diff)
hf1_53 = get_headloss_friction(0.53,height_diff)
hf1_58 = get_headloss_friction(0.58,height_diff)
flow_rate_38 = get_flowrate(hf1_38,bends)
flow_rate_43 = get_flowrate(hf1_43,bends)
flow_rate_48 = get_flowrate(hf1_48,bends)
flow_rate_53 = get_flowrate(hf1_53,bends)
flow_rate_58 = get_flowrate(hf1_58,bends)
x = [0.58, 0.53,0.48,0.43,0.38]
flowrate = [flow_rate_58,flow_rate_53,flow_rate_48,flow_rate_43,flow_rate_38]
fig1, ax1 = plt.subplots(1,1)

#ax1.plot(heights,avg_slopes,label = 'Experimental Results - Raw')
ax1.plot(x,flowrate, label = 'Model Fitting Results')
#ax1.errorbar(x,avg_slopes,yerr = error_bars,label = 'Experimental Results - Raw')

regres_slope_model = plot_slope2(x,flowrate,ax1,True,False)
regres_slope_exp = plot_slope2(x,avg_slopes,ax1,True,True)


ax1.set_xlabel('Height (m)')
ax1.set_ylabel('Flow Rate (mL/min)')
ax1.legend()
ax1.grid()
ax1.set_title('12cm Head Pressure - Comparing Model Fit With Experimental Results')
print('Model slope',regres_slope_model)
print('Experimental slope',regres_slope_exp)
print(regres_slope)
print(flowrate )
print(avg_slopes)
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# Model slope 4.072268810857224
# Experimental slope 4.006374412423155
# 4.006374412423156
# [2.342478872363025, 2.140443566177264, 1.9373660068201024, 1.7332298956856023, 1.5280185048945503]
# [2.3760307254623045, 2.2267360617760614, 1.994823166023166, 1.8213286153846155, 1.5771408455522389]
