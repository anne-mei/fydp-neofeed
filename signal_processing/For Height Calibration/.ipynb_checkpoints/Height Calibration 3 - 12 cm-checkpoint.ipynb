# %% [markdown]
# - TO DO: Sample at least 50 seconds before and after points (get a total of 100 s - 20 dp)

# %%
# %matplotlib nbagg
#Import required libraries
from serial import Serial
import csv
import time
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
from drawnow import drawnow, figure
from scipy import stats
import scipy.signal as signal
import pandas as pd

# %%
def plot_slope(x,y,ax):
    slope, intercept, r, p, std_err = stats.linregress(x, y)
    def myfunc(x):
        return slope * x + intercept
    mymodel = list(map(myfunc, x))
    ax.plot(x,y)
    ax.plot(x, mymodel)
    print(myfunc(0.2))
    return slope

# %% [markdown]
# # 89 cm

# %%
#Read real data
csv_name = r'\Height Calibration Trials - 89.csv'
csv_path =r'C:\Users\a_hop\repos\fydp-neofeed\sensor_data\2022-02-19 Height Calibration Straight Tube'+csv_name
csv_data = pd.read_csv(csv_path)

time = csv_data['Time']

#Initialize plot
fig, (ax1, ax2,ax3) = plt.subplots(3)

trial_1_slope = plot_slope(time[csv_data['Trial 1'].notna()],csv_data['Trial 1'].dropna(),ax1)
trial_2_slope = plot_slope(time[csv_data['Trial 2'].notna()],csv_data['Trial 2'].dropna(),ax2)
trial_3_slope = plot_slope(time[csv_data['Trial 3'].notna()],csv_data['Trial 3'].dropna(),ax3)
#print(trial_1_slope)
avg_slope_89 = (1/2)*(trial_1_slope +trial_2_slope+trial_3_slope)

print("\nTrial 1 Slope: "+str(trial_1_slope))
print("\nTrial 2 Slope: "+ str(trial_2_slope))
print("\nTrial 3 Slope: "+ str(trial_3_slope))
print("\nAvg slope: "+ str(avg_slope_89))
# Out:
# <img src="data:image/png;base64,..." width="959.9999856948855">
# Trial 1 Slope: 0.08382332015810276
#
# Trial 2 Slope: 0.0890749226006192
#
# Trial 3 Slope: 0.08974644268774702
#
# Avg slope: 0.13132234272323448

# %% [markdown]
# # 73cm

# %%
#Read real data
csv_name = r'\Height Calibration Trials - 73.csv'
csv_path =r'C:\Users\a_hop\repos\fydp-neofeed\sensor_data\2022-02-19 Height Calibration Straight Tube'+csv_name
csv_data = pd.read_csv(csv_path)

time = csv_data['Time']

#Initialize plot
fig, (ax1, ax2,ax3) = plt.subplots(3)

trial_1_slope = plot_slope(time[csv_data['Trial 1'].notna()],csv_data['Trial 1'].dropna(),ax1)
trial_2_slope = plot_slope(time[csv_data['Trial 2'].notna()],csv_data['Trial 2'].dropna(),ax2)
trial_3_slope = plot_slope(time[csv_data['Trial 3'].notna()],csv_data['Trial 3'].dropna(),ax3)
#print(trial_1_slope)
avg_slope_73 = (1/3)*(trial_1_slope +trial_2_slope+trial_3_slope)

print("\nTrial 1 Slope: "+str(trial_1_slope))
print("\nTrial 2 Slope: "+ str(trial_2_slope))
print("\nTrial 3 Slope: "+ str(trial_3_slope))
print("\nAvg slope: "+ str(avg_slope_73))
# Out:
# <img src="data:image/png;base64,..." width="959.9999856948855">
# Trial 1 Slope: 0.07467969230769231
#
# Trial 2 Slope: 0.07511826086956522
#
# Trial 3 Slope: 0.07178165217391305
#
# Avg slope: 0.07385986845039019

# %% [markdown]
# #  63 cm

# %%
#Read real data
csv_name = r'\Height Calibration Trials - 63.csv'
csv_path =r'C:\Users\a_hop\repos\fydp-neofeed\sensor_data\2022-02-19 Height Calibration Straight Tube'+csv_name
csv_data = pd.read_csv(csv_path)

time = csv_data['Time']

#Initialize plot
fig, (ax1, ax2,ax3) = plt.subplots(3)

trial_1_slope = plot_slope(time[csv_data['Trial 1'].notna()],csv_data['Trial 1'].dropna(),ax1)
trial_2_slope = plot_slope(time[csv_data['Trial 2'].notna()],csv_data['Trial 2'].dropna(),ax2)
trial_3_slope = plot_slope(time[csv_data['Trial 3'].notna()],csv_data['Trial 3'].dropna(),ax3)
#print(trial_1_slope)
avg_slope_63 = (1/3)*(trial_1_slope +trial_2_slope+trial_3_slope)

print("\nTrial 1 Slope: "+str(trial_1_slope))
print("\nTrial 2 Slope: "+ str(trial_2_slope))
print("\nTrial 3 Slope: "+ str(trial_3_slope))
print("\nAvg slope: "+ str(avg_slope_63))
# Out:
# <img src="data:image/png;base64,..." width="959.9999856948855">
# Trial 1 Slope: 0.06603307692307692
#
# Trial 2 Slope: 0.06461092307692307
#
# Trial 3 Slope: 0.061956923076923076
#
# Avg slope: 0.06420030769230768

# %% [markdown]
# # 53 cm

# %%
#Read real data
csv_name = r'\Height Calibration Trials - 53.csv'
csv_path =r'C:\Users\a_hop\repos\fydp-neofeed\sensor_data\2022-02-19 Height Calibration Straight Tube'+csv_name
csv_data = pd.read_csv(csv_path)

time = csv_data['Time']

#Initialize plot
fig, (ax1, ax2,ax3) = plt.subplots(3)

trial_1_slope = plot_slope(time[csv_data['Trial 1'].notna()],csv_data['Trial 1'].dropna(),ax1)
trial_2_slope = plot_slope(time[csv_data['Trial 2'].notna()],csv_data['Trial 2'].dropna(),ax2)
trial_3_slope = plot_slope(time[csv_data['Trial 3'].notna()],csv_data['Trial 3'].dropna(),ax3)
print(trial_1_slope)
avg_slope_53 = (1/3)*(trial_1_slope +trial_2_slope+trial_3_slope)

print("\nTrial 1 Slope: "+str(trial_1_slope))
print("\nTrial 2 Slope: "+ str(trial_2_slope))
print("\nTrial 3 Slope: "+ str(trial_3_slope))
print("\nAvg slope: "+ str(avg_slope_53))
# Out:
# <img src="data:image/png;base64,..." width="959.9999856948855">
# 0.052923157894736846
#
# Trial 1 Slope: 0.052923157894736846
#
# Trial 2 Slope: 0.05347569230769231
#
# Trial 3 Slope: 0.05034246153846154
#
# Avg slope: 0.05224710391363022

# %% [markdown]
# # 43 cm

# %%
#Read real data
csv_name = r'\Height Calibration Trials - 43.csv'
csv_path =r'C:\Users\a_hop\repos\fydp-neofeed\sensor_data\2022-02-19 Height Calibration Straight Tube'+csv_name
csv_data = pd.read_csv(csv_path)

time = csv_data['Time']

#Initialize plot
fig, (ax1, ax2,ax3) = plt.subplots(3)

#trial_1_slope = plot_slope(time[csv_data['Trial 1'].notna()],csv_data['Trial 1'].dropna(),ax1)
trial_2_slope = plot_slope(time[csv_data['Trial 2'].notna()],csv_data['Trial 2'].dropna(),ax2)
trial_3_slope = plot_slope(time[csv_data['Trial 3'].notna()],csv_data['Trial 3'].dropna(),ax3)
#print(trial_1_slope)
avg_slope_43 = (1/2)*(trial_2_slope+trial_3_slope)

#print("\nTrial 1 Slope: "+str(trial_1_slope))
print("\nTrial 2 Slope: "+ str(trial_2_slope))
print("\nTrial 3 Slope: "+ str(trial_3_slope))
print("\nAvg slope: "+ str(avg_slope_43))
# Out:
# <img src="data:image/png;base64,..." width="959.9999856948855">
# Trial 2 Slope: 0.043548461538461536
#
# Trial 3 Slope: 0.043569230769230784
#
# Avg slope: 0.043558846153846156

# %% [markdown]
# # Final Cali Slope

# %%
avg_slopes = [ avg_slope_73,avg_slope_63]
density_milk =1 
sec_to_min = 60
avg_flowrate = [x*sec_to_min*density_milk for x in avg_slopes]
print(avg_flowrate)
heights = [0.73,0.63]

fig3, ax1 = plt.subplots(1,1)
ax1.plot(heights,avg_flowrate)
ax1.set_xlabel('Height (m)')
ax1.set_ylabel('Flow Rate (mL/min)')
regres_slope = plot_slope(heights,avg_flowrate,ax1)
print('Calibration slope: '+ str(regres_slope))
#print('Calibration intercept: '+str(regres_intercept))
# Out:
# [4.431592107023412, 3.852018461538461]
# <img src="data:image/png;base64,..." width="639.999974568686">
# 1.3598517859531722
# Calibration slope: 5.795736454849509
