# %% [markdown]
# - TO DO: Sample at least 50 seconds before and after points (get a total of 100 s - 20 dp)

# %%
# %matplotlib nbagg
#Import required libraries
# from serial import Serial
import csv
import time
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
# from drawnow import drawnow, figure
from scipy import stats
import scipy.signal as signal
import pandas as pd

# %%
def plot_slope(x,y,ax,is_final):
    slope, intercept, r, p, std_err = stats.linregress(x, y)
    def myfunc(x):
        return slope * x + intercept
    mymodel = list(map(myfunc, x))
    #ax.plot(x,y)
    ax.plot(x, mymodel)
    density_milk =1 
    sec_to_min = 60
    if is_final is False:
        slope = slope*sec_to_min*density_milk
    return slope

def plot_slope2(x,y,ax,is_final,is_plot):
    slope, intercept, r, p, std_err = stats.linregress(x, y)
    def myfunc(x):
        return slope * x + intercept
    mymodel = list(map(myfunc, x))
    #ax.plot(x,y)
    if is_plot:
        ax.plot(x, mymodel,label = 'Experimental Results - Lin Reg')
    density_milk =1 
    sec_to_min = 60
    if is_final is False:
        slope = slope*sec_to_min*density_milk
    return slope, mymodel

# %% [markdown]
# # 14.4cm

# %%
#Read real data
csv_name = r'\Height Cal 50mL - 14.4cm.csv'
csv_path =r'C:\Users\a_hop\repos\fydp-neofeed\sensor_data\2022-03-13 Height Calibration 50mL'+csv_name
csv_data = pd.read_csv(csv_path)
#csv_data = csv_data.head(25)
time = csv_data['Time']

#Initialize plot
fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(5)

trial_1_slope = plot_slope(time[csv_data['Trial 1'].notna()],csv_data['Trial 1'].dropna(),ax1,False)
trial_2_slope = plot_slope(time[csv_data['Trial 2'].notna()],csv_data['Trial 2'].dropna(),ax2,False)
trial_3_slope = plot_slope(time[csv_data['Trial 3'].notna()],csv_data['Trial 3'].dropna(),ax3,False)
trial_4_slope = plot_slope(time[csv_data['Trial 4'].notna()],csv_data['Trial 4'].dropna(),ax4,False)
trial_5_slope = plot_slope(time[csv_data['Trial 5'].notna()],csv_data['Trial 5'].dropna(),ax5,False)
all_slopes_14 = [trial_2_slope, trial_3_slope, trial_4_slope, trial_5_slope]
avg_slope_14 = np.mean(all_slopes_14)
max_error_14 = np.max(all_slopes_14)-avg_slope_14 
min_error_14 = avg_slope_14 - np.min(all_slopes_14)

print("\nTrial 1 Slope: "+str(trial_1_slope))
print("\nTrial 2 Slope: "+ str(trial_2_slope))
print("\nTrial 3 Slope: "+ str(trial_3_slope))
print("\nTrial 4 Slope: "+ str(trial_4_slope))
print("\nTrial 5 Slope: "+ str(trial_5_slope))
print("\nAvg slope: "+ str(avg_slope_14))
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# Trial 1 Slope: 1.1567065628476083
#
# Trial 2 Slope: 1.056145092460882
#
# Trial 3 Slope: 1.035342816500711
#
# Trial 4 Slope: 1.0252916073968708
#
# Trial 5 Slope: 1.0117980085348504
#
# Avg slope: 1.0321443812233286

# %% [markdown]
# # 19.4cm

# %%
#Read real data
csv_name = r'\Height Cal 50mL - 19.4cm.csv'
csv_path =r'C:\Users\a_hop\repos\fydp-neofeed\sensor_data\2022-03-13 Height Calibration 50mL'+csv_name
csv_data = pd.read_csv(csv_path)
#csv_data = csv_data.head(25)
time = csv_data['Time']

#Initialize plot
fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(5)

trial_1_slope = plot_slope(time[csv_data['Trial 1'].notna()],csv_data['Trial 1'].dropna(),ax1,False)
trial_2_slope = plot_slope(time[csv_data['Trial 2'].notna()],csv_data['Trial 2'].dropna(),ax2,False)
trial_3_slope = plot_slope(time[csv_data['Trial 3'].notna()],csv_data['Trial 3'].dropna(),ax3,False)
trial_4_slope = plot_slope(time[csv_data['Trial 4'].notna()],csv_data['Trial 4'].dropna(),ax4,False)
trial_5_slope = plot_slope(time[csv_data['Trial 5'].notna()],csv_data['Trial 5'].dropna(),ax5,False)

all_slopes_19 = [trial_1_slope, trial_2_slope, trial_3_slope, trial_4_slope]
avg_slope_19 = np.mean(all_slopes_19)
max_error_19 = np.max(all_slopes_19)-avg_slope_19 
min_error_19 = avg_slope_19 - np.min(all_slopes_19)

print("\nTrial 1 Slope: "+str(trial_1_slope))
print("\nTrial 2 Slope: "+ str(trial_2_slope))
print("\nTrial 3 Slope: "+ str(trial_3_slope))
print("\nTrial 4 Slope: "+ str(trial_4_slope))
print("\nTrial 5 Slope: "+ str(trial_5_slope))
print("\nAvg slope: "+ str(avg_slope_19))
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# Trial 1 Slope: 1.1206372688477952
#
# Trial 2 Slope: 1.1348677098150781
#
# Trial 3 Slope: 1.1199800853485067
#
# Trial 4 Slope: 1.1274765291607394
#
# Trial 5 Slope: 9.985467994310103
#
# Avg slope: 1.12574039829303

# %% [markdown]
# # 24.4cm

# %%
#Read real data
csv_name = r'\Height Cal 50mL - 24.4cm.csv'
csv_path =r'C:\Users\a_hop\repos\fydp-neofeed\sensor_data\2022-03-13 Height Calibration 50mL'+csv_name
csv_data = pd.read_csv(csv_path)
#csv_data = csv_data.head(25)
time = csv_data['Time']

#Initialize plot
fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(5)

trial_1_slope = plot_slope(time[csv_data['Trial 1'].notna()],csv_data['Trial 1'].dropna(),ax1,False)
trial_2_slope = plot_slope(time[csv_data['Trial 2'].notna()],csv_data['Trial 2'].dropna(),ax2,False)
trial_3_slope = plot_slope(time[csv_data['Trial 3'].notna()],csv_data['Trial 3'].dropna(),ax3,False)
trial_4_slope = plot_slope(time[csv_data['Trial 4'].notna()],csv_data['Trial 4'].dropna(),ax4,False)
trial_5_slope = plot_slope(time[csv_data['Trial 5'].notna()],csv_data['Trial 5'].dropna(),ax5,False)
all_slopes_24 = [ trial_3_slope, trial_4_slope, trial_5_slope]
avg_slope_24 = np.mean(all_slopes_24)
max_error_24 = np.max(all_slopes_24)-avg_slope_24
min_error_24 = avg_slope_24 - np.min(all_slopes_24)

print("\nTrial 1 Slope: "+str(trial_1_slope))
print("\nTrial 2 Slope: "+ str(trial_2_slope))
print("\nTrial 3 Slope: "+ str(trial_3_slope))
print("\nTrial 4 Slope: "+ str(trial_4_slope))
print("\nTrial 5 Slope: "+ str(trial_5_slope))
print("\nAvg slope: "+ str(avg_slope_24))
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# Trial 1 Slope: 1.3092660028449508
#
# Trial 2 Slope: 1.3319544807965864
#
# Trial 3 Slope: 1.2448079658605975
#
# Trial 4 Slope: 1.2338975817923188
#
# Trial 5 Slope: 1.2088421052631575
#
# Avg slope: 1.2291825509720247

# %% [markdown]
# # Final Cali Slope

# %%
avg_slopes = [ avg_slope_24,avg_slope_19, avg_slope_14]
error_bars = [[max_error_24,max_error_19,max_error_14],[min_error_24,min_error_19,min_error_14]]
density_milk =1 
sec_to_min = 60
heights = [0.244,0.194,0.144]
print(avg_slopes)
fig3, ax1 = plt.subplots(1,1)
ax1.plot(heights,avg_slopes)
ax1.errorbar(heights,avg_slopes,yerr = error_bars)
ax1.set_xlabel('Height (m)')
ax1.set_ylabel('Flow Rate (mL/min)')
regres_slope = plot_slope(heights,avg_slopes,ax1,True)
print('Calibration slope: '+ str(regres_slope))
#print('Calibration intercept: '+str(regres_intercept))
# Out:
# [1.2291825509720247, 1.12574039829303, 1.0321443812233286]
# <img src="data:image/png;base64,..." width="639.999974568686">
# Calibration slope: 1.97038169748696

# %%
from scipy import stats
#assumtions:
    #assume laminar flow (Nre < 2000)
    #assume alpha = 1 (velocity profile at max)
    #assume v1 = 0 (very small flow at the start)
    #assume 1 bend for an empty bag
import math
# variables:
g = 9.81              # gravity (m/s^2)
#q2 = 3.3333 * 10**-8  # flow rate going into baby(m^3/s)
d = 0.0011    # internal tube diameter for 5 French (m)
rho = 1035           # density of milk (kg/m^3)
l_total = 0.875       # total length of tube (m)
mu = 0.00584     # viscosity of milk (Pa*s)
#mu = 0.0126
h_full = 0.22       #height of fluid in syringe (m) (0.084)
p0 = 0                # atmospheric gauge pressure 
p1 = p0 + rho*g*h_full
#h_diff = 0.15          #Height between top of syringe and bottom of tube -----> CHANGE
#p2 = rho*g*h_diff # pressure in baby's stomach (Pa)
bends =8000

def get_flowrate(hf,bends):
    #v2 = (hf*rho*d**2)/(32*mu*l_total)
    v2 = 0
    a = bends
    b = 64*mu*l_total/(rho*d**2)
    c = -2*hf
    v2_1 = (-b + (b ** 2 - 4 * a * c) ** 0.5) / (2 * a)
    v2_2 = (-b - (b ** 2 - 4 * a * c) ** 0.5) / (2 * a)
    if v2_2>=v2_1:
        v2 = v2_2
    else:
        v2 = v2_1
    #v2 = (hf*rho*d**2)/(32*mu*l_total)
    flow_rate = v2*math.pi*(d/2)**2
    convertion_rate = 6*10**7
    return flow_rate*convertion_rate

def get_headloss_friction(h,h_diff):
    p2 = rho*g*h_diff # pressure in baby's stomach (Pa)
    hf = (g*h)-(p2-p1)/rho
    return hf

def plot_slope(x,y,ax):
    slope, intercept, r, p, std_err = stats.linregress(x, y)
    def myfunc(x):
        return slope * x + intercept
    mymodel = list(map(myfunc, x))
    ax.plot(x,y)
    ax.plot(x, mymodel)
    return slope
#if __name__ == '__main__':
    #v2 = get_velocity_into_baby();


#SOLVE FOR 6.5 FRENCH:
    # print('\nSolved Heights for 6 French Tubing:')
    # # CASE 1: 1 Bend at mouth (90 degrees) (bag is empty)
    # hf1 = get_headloss_friction(get_velocity_into_baby(d_6French), k_bend_90deg, d_6French);
    # h_empty = get_height(hf1, 0, d_6French);
    # print('The height for an empty bag of feed should be', round(h_empty, 4), 'm above the baby\'s stomach')

    # #CASE 2: 2 Bends, one at mouth (90 degrees), one at 45 degree (bag is half empty)
    # hf2 = get_headloss_friction(get_velocity_into_baby(d_6French), k_bend_90deg + k_bend_45deg,d_6French);
    # h_semifull = get_height(hf2,p1_half_full,d_6French);
    # print('The height for a semi-full bag of feed should be', round(h_semifull, 4),'m above the baby\'s stomach')

    # #CASE 3: 2 Bends, one at mouth (90 degrees), one at 90 degree (bag is full)
    # hf3 = get_headloss_friction(get_velocity_into_baby(d_6French), k_bend_90deg + k_bend_90deg,d_6French);
    # h_fullbag = get_height(hf3, p1_full,d_6French);
    # print('The height for a full bag of feed should be', round(h_fullbag, 4), 'm above the baby\'s stomach')

# %%
from sklearn.metrics import mean_squared_error

# %%
#bends = find_best_bends()
diffs = []

height_diff  = 0
hf1_14 = get_headloss_friction(0.144,height_diff)
hf1_19 = get_headloss_friction(0.194,height_diff)
hf1_24 = get_headloss_friction(0.244,height_diff)

flow_rate_14 = get_flowrate(hf1_14,bends)
flow_rate_19 = get_flowrate(hf1_19,bends)
flow_rate_24 = get_flowrate(hf1_24,bends)

x= [0.244, 0.194,0.144]
flowrate = [flow_rate_24,flow_rate_19,flow_rate_14]
fig1, ax1 = plt.subplots(1,1)

ax1.plot(heights,avg_slopes,label = 'Experimental Results - Raw')
ax1.plot(x,flowrate, label = 'Model Fitting Results')
ax1.errorbar(x,avg_slopes,yerr = error_bars,label = 'Experimental Results - Raw')

regres_slope_model, regres_slope_model_intercept = plot_slope2(x,flowrate,ax1,True,False)
regres_slope_exp, regres_slope_exp_data = plot_slope2(x,avg_slopes,ax1,True,True)

# get mse between flowrate and regres_slope_exp_data

ax1.set_xlabel('Height (m)')
ax1.set_ylabel('Flow Rate (mL/min)')
print('Model slope',regres_slope_model)
print('Experimental slope',regres_slope_exp)
ax1.legend()
ax1.grid()
ax1.set_title('24cm Head Pressure - Comparing Model Fit With Experimental Results')
print(flowrate )
print(avg_slopes)
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# Model slope 1.9552734025497018
# Experimental slope 1.97038169748696
# [1.2061580616597174, 1.1107367377596633, 1.0106307214047472]
# [1.2291825509720247, 1.12574039829303, 1.0321443812233286]
