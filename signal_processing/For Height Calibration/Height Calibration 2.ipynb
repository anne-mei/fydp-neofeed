# %% [markdown]
# - TO DO: Sample at least 50 seconds before and after points (get a total of 100 s - 20 dp)

# %%
# %matplotlib nbagg
#Import required libraries
from serial import Serial
import csv
import time
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
from drawnow import drawnow, figure
from scipy import stats
import scipy.signal as signal
import pandas as pd

# %%
def plot_slope(x,y,ax):
    slope, intercept, r, p, std_err = stats.linregress(x, y)
    def myfunc(x):
        return slope * x + intercept
    mymodel = list(map(myfunc, x))
    ax.plot(x,y)
    ax.plot(x, mymodel)
    return slope

# %% [markdown]
# # 89 cm

# %%
#Read real data
csv_name = r'\Height Calibration Trials - 89.csv'
csv_path =r'C:\Users\a_hop\repos\fydp-neofeed\sensor_data\2022-02-22 Height Calibration Straight Tube'+csv_name
csv_data = pd.read_csv(csv_path)

time = csv_data['Time']

#Initialize plot
fig, (ax1, ax2,ax3) = plt.subplots(3)

trial_1_slope = plot_slope(time[csv_data['Trial 1'].notna()],csv_data['Trial 1'].dropna(),ax1)
trial_2_slope = plot_slope(time[csv_data['Trial 2'].notna()],csv_data['Trial 2'].dropna(),ax2)
trial_3_slope = plot_slope(time[csv_data['Trial 3'].notna()],csv_data['Trial 3'].dropna(),ax3)
#print(trial_1_slope)
avg_slope_89 = (1/2)*(trial_1_slope +trial_2_slope+trial_3_slope)

print("\nTrial 1 Slope: "+str(trial_1_slope))
print("\nTrial 2 Slope: "+ str(trial_2_slope))
print("\nTrial 3 Slope: "+ str(trial_3_slope))
print("\nAvg slope: "+ str(avg_slope_89))
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# Trial 1 Slope: 0.09388809523809521
#
# Trial 2 Slope: 0.10869666666666669
#
# Trial 3 Slope: 0.08769818181818181
#
# Avg slope: 0.14514147186147186

# %% [markdown]
# # 73cm

# %%
#Read real data
csv_name = r'\Height Calibration Trials - 73.csv'
csv_path =r'C:\Users\a_hop\repos\fydp-neofeed\sensor_data\2022-02-22 Height Calibration Straight Tube'+csv_name
csv_data = pd.read_csv(csv_path)

time = csv_data['Time']

#Initialize plot
fig, (ax1, ax2,ax3) = plt.subplots(3)

trial_1_slope = plot_slope(time[csv_data['Trial 1'].notna()],csv_data['Trial 1'].dropna(),ax1)
trial_2_slope = plot_slope(time[csv_data['Trial 2'].notna()],csv_data['Trial 2'].dropna(),ax2)
trial_3_slope = plot_slope(time[csv_data['Trial 3'].notna()],csv_data['Trial 3'].dropna(),ax3)
#print(trial_1_slope)
avg_slope_73 = (1/3)*(trial_1_slope +trial_2_slope+trial_3_slope)

print("\nTrial 1 Slope: "+str(trial_1_slope))
print("\nTrial 2 Slope: "+ str(trial_2_slope))
print("\nTrial 3 Slope: "+ str(trial_3_slope))
print("\nAvg slope: "+ str(avg_slope_73))
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# Trial 1 Slope: 0.07783515151515151
#
# Trial 2 Slope: 0.07796999999999998
#
# Trial 3 Slope: 0.07192000000000001
#
# Avg slope: 0.07590838383838383

# %% [markdown]
# #  63 cm

# %%
#Read real data
csv_name = r'\Height Calibration Trials - 63.csv'
csv_path =r'C:\Users\a_hop\repos\fydp-neofeed\sensor_data\2022-02-22 Height Calibration Straight Tube'+csv_name
csv_data = pd.read_csv(csv_path)

time = csv_data['Time']

#Initialize plot
fig, (ax1, ax2,ax3) = plt.subplots(3)

trial_1_slope = plot_slope(time[csv_data['Trial 1'].notna()],csv_data['Trial 1'].dropna(),ax1)
trial_2_slope = plot_slope(time[csv_data['Trial 2'].notna()],csv_data['Trial 2'].dropna(),ax2)
trial_3_slope = plot_slope(time[csv_data['Trial 3'].notna()],csv_data['Trial 3'].dropna(),ax3)
#print(trial_1_slope)
avg_slope_63 = (1/3)*(trial_1_slope +trial_2_slope+trial_3_slope)

print("\nTrial 1 Slope: "+str(trial_1_slope))
print("\nTrial 2 Slope: "+ str(trial_2_slope))
print("\nTrial 3 Slope: "+ str(trial_3_slope))
print("\nAvg slope: "+ str(avg_slope_63))
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# Trial 1 Slope: 0.06832417582417583
#
# Trial 2 Slope: 0.06641090909090909
#
# Trial 3 Slope: 0.06413636363636364
#
# Avg slope: 0.06629048285048285

# %% [markdown]
# # 53 cm

# %%
#Read real data
csv_name = r'\Height Calibration Trials - 53.csv'
csv_path =r'C:\Users\a_hop\repos\fydp-neofeed\sensor_data\2022-02-22 Height Calibration Straight Tube'+csv_name
csv_data = pd.read_csv(csv_path)

time = csv_data['Time']

#Initialize plot
fig, (ax1, ax2,ax3) = plt.subplots(3)

trial_1_slope = plot_slope(time[csv_data['Trial 1'].notna()],csv_data['Trial 1'].dropna(),ax1)
trial_2_slope = plot_slope(time[csv_data['Trial 2'].notna()],csv_data['Trial 2'].dropna(),ax2)
trial_3_slope = plot_slope(time[csv_data['Trial 3'].notna()],csv_data['Trial 3'].dropna(),ax3)
#print(trial_1_slope)
avg_slope_53 = (1/3)*(trial_1_slope +trial_2_slope+trial_3_slope)

print("\nTrial 1 Slope: "+str(trial_1_slope))
print("\nTrial 2 Slope: "+ str(trial_2_slope))
print("\nTrial 3 Slope: "+ str(trial_3_slope))
print("\nAvg slope: "+ str(avg_slope_53))
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# Trial 1 Slope: 0.05274335664335665
#
# Trial 2 Slope: 0.054470629370629374
#
# Trial 3 Slope: 0.0500912087912088
#
# Avg slope: 0.05243506493506493

# %% [markdown]
# # 43 cm

# %%
#Read real data
csv_name = r'\Height Calibration Trials - 43.csv'
csv_path =r'C:\Users\a_hop\repos\fydp-neofeed\sensor_data\2022-02-22 Height Calibration Straight Tube'+csv_name
csv_data = pd.read_csv(csv_path)

time = csv_data['Time']

#Initialize plot
fig, (ax1, ax2,ax3) = plt.subplots(3)

trial_1_slope = plot_slope(time[csv_data['Trial 1'].notna()],csv_data['Trial 1'].dropna(),ax1)
trial_2_slope = plot_slope(time[csv_data['Trial 2'].notna()],csv_data['Trial 2'].dropna(),ax2)
trial_3_slope = plot_slope(time[csv_data['Trial 3'].notna()],csv_data['Trial 3'].dropna(),ax3)
#print(trial_1_slope)
avg_slope_43 = (1/3)*(trial_1_slope +trial_2_slope+trial_3_slope)

print("\nTrial 1 Slope: "+str(trial_1_slope))
print("\nTrial 2 Slope: "+ str(trial_2_slope))
print("\nTrial 3 Slope: "+ str(trial_3_slope))
print("\nAvg slope: "+ str(avg_slope_43))
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# Trial 1 Slope: 0.04562307692307693
#
# Trial 2 Slope: 0.04310285714285714
#
# Trial 3 Slope: 0.04346928571428572
#
# Avg slope: 0.04406507326007326

# %% [markdown]
# # Final Cali Slope

# %%
avg_slopes = [avg_slope_89,avg_slope_73,avg_slope_63, avg_slope_53, avg_slope_43]
density_milk =1 
sec_to_min = 60
avg_flowrate = [x*sec_to_min*density_milk for x in avg_slopes]
print(avg_flowrate)
heights = [0.89,0.73,0.63,0.53,0.43]

fig3, ax1 = plt.subplots(1,1)
ax1.plot(heights,avg_flowrate)
ax1.set_xlabel('Height (cm)')
ax1.set_ylabel('Flow Rate (mL/min)')
regres_slope = plot_slope(heights,avg_flowrate,ax1)
print('Calibration slope: '+ str(regres_slope))
#print('Calibration intercept: '+str(regres_intercept))
# Out:
# [8.708488311688312, 4.55450303030303, 3.9774289710289708, 3.146103896103896, 2.6439043956043955]
# <img src="data:image/png;base64,..." width="639.999974568686">
# Calibration slope: 12.609559048559676
